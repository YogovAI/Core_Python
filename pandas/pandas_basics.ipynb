# %%
import pandas as pd
import numpy as np
import multiprocessing as mp
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("nyc_weather.csv")
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
row_count = df.shape[0]

# %%
df = pd.Series([row_count], name='Row Count')

# %%
df.head()
# Out:
# 0    31
# Name: Row Count, dtype: int64

# %%
chunksize = 2
for i in pd.read_csv('nyc_weather.csv', chunksize=16):
    num_chunks = mp.cpu_count()
    print(num_chunks)
    print(type(i))
    data_lst = np.array_split(i, 4)
    print(type(data_lst))
    print(data_lst)
    print(".....................")
    print(data_lst.shape[0])
# Out:
# 16
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# [        EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345  ,         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# ...

# %%
partitions = mp.cpu_count()
print(partitions)

data_chunks = np.array_split(df, partitions)
# Out:
# 16
# /home/yogesh/anaconda3/envs/Pytorch_12_1/lib/python3.11/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
data_chunks
# Out:
# [        EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
#  0  1/1/2016           38        23        52                 30.03
#  1  1/2/2016           36        18        46                 30.02
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
#  0               10           8.0               0           5    NaN
#  1               10           7.0               0           3    NaN
#
#     WindDirDegrees
#  0             281
#  1             275  ,
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
#  2  1/3/2016           40        21        47                 29.86
#  3  1/4/2016           25         9        44                 30.05
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
#  2               10           8.0               0           1    NaN
#  3               10           9.0               0           3    NaN
#
#     WindDirDegrees
#  2             277
#  3             345  ,
# ...

# %%
type(data_chunks)
# Out:
# list

# %%
data_chunks.shape[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data_chunks.shape[0]
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
import pandas as pd

# %%
world = [["Afghanistan", "Asia", 652230, 25500100, 20343000000],
         ["Albania", "Europe", 28748, 2831741, 12960000000],
         ["Algeria", "Africa", 2381741, 37100000, 188681000000],
         ["Andorra", "Europe", 468, 78115, 3712000000],
         ["Angola", "Africa", 1246700, 20609294, 100990000000]]   

world
# Out:
# [['Afghanistan', 'Asia', 652230, 25500100, 20343000000],
#  ['Albania', 'Europe', 28748, 2831741, 12960000000],
#  ['Algeria', 'Africa', 2381741, 37100000, 188681000000],
#  ['Andorra', 'Europe', 468, 78115, 3712000000],
#  ['Angola', 'Africa', 1246700, 20609294, 100990000000]]

# %%
df = pd.DataFrame(world, columns = ["name", "continent", "area", "population", "gdp"])
df
# Out:
#           name continent     area  population           gdp
# 0  Afghanistan      Asia   652230    25500100   20343000000
# 1      Albania    Europe    28748     2831741   12960000000
# 2      Algeria    Africa  2381741    37100000  188681000000
# 3      Andorra    Europe      468       78115    3712000000
# 4       Angola    Africa  1246700    20609294  100990000000

# %%
df1 = df[(df["area"] > 3000000) | (df['population'] > 25000000)]
df1
# Out:
#           name continent     area  population           gdp
# 0  Afghanistan      Asia   652230    25500100   20343000000
# 2      Algeria    Africa  2381741    37100000  188681000000
